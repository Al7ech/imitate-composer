# %%
import note_seq
from note_seq.midi_io import midi_to_note_sequence

# %%
data = open("test.mid", "rb").read()
test = midi_to_note_sequence(data)
note_seq.plot_sequence(test)
note_seq.play_sequence(test,synth=note_seq.synthesize)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1356">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="1ced0e88-129a-4323-99bc-16ae838a9421" data-root-id="1310"></div>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
